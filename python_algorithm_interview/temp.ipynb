# %%
x="""
구현,문자열,그래프,최단경로,비트마스크,그리디,트리DP,자료구조,이분탐색,
구현,시뮬레이션,BFS,완전탐색,
BFS,시뮬레이션,
구현,시뮬레이션,BFS,DP,완전탐색,
BFS,시뮬레이션,
BFS,시뮬레이션,
투포인터,완전탐색,DP,트라이,파싱,최단경로,이분탐색,
구현,문자열,
문자열,재귀,탐색,트라이,구현,완전탐색,BFS,
구현,완전탐색,투포인터,BFS,DFS,트리,유니온파인드,
배열,해싱,map,정렬,조합,DFS,정렬,시뮬레이션,트리순회,구현,
BFS,세그먼트트리,완전탐색,자료구조,다익스트라,
구현,정렬,문자열,트라이,
Bitwise,문자열,구현,정렬,시뮬레이션,스케쥴링,
구현,문자열,시뮬레이션,덱,
구현,BFS,DFS,DP,
모노톤스택,그래프,
플러드필,
구현,시뮬레이션,
Trie,비트마스킹,
구현,시뮬레이션,
DFS,DP,
BFS,시뮬레이션,
유니온파인드,문자열,우선순위큐,완전탐색,[SQL],
정렬,위상정렬,트리DP,해싱(Map),
구현,완전탐색,트리,DP,
문자열,DP,순열조합,
Heap,구현,순열,BFS,
트리,조합,파싱,구현,
"""

x.split(",")
# Out:
# ['\n구현',
#  ' 문자열',
#  ' 그래프',
#  ' 최단경로',
#  ' 비트마스크',
#  ' 그리디',
#  ' 트리DP',
#  ' 자료구조',
#  ' 이분탐색',
#  '\n구현',
#  ' 시뮬레이션',
#  ' BFS',
#  ' 완전탐색',
#  '\nBFS',
#  ' 시뮬레이션',
#  '\n구현',
#  ' 시뮬레이션',
#  ' BFS',
#  ' DP',
#  ' 완전탐색',
#  '\nBFS',
#  ' 시뮬레이션',
#  '\nBFS',
#  ' 시뮬레이션',
#  '\n투포인터',
#  ' 완전탐색',
#  ' DP',
#  ' 트라이',
#  ' 파싱',
#  ' 최단경로',
#  ' 이분탐색',
#  '\n구현',
#  ' 문자열',
#  '\n문자열',
#  ' 재귀',
#  ' 탐색',
#  ' 트라이',
#  ' 구현',
#  ' 완전탐색',
#  ' BFS',
#  '\n구현',
#  ' 완전탐색',
#  ' 투포인터',
#  ' BFS',
#  ' DFS',
#  ' 트리',
#  ' 유니온파인드 ',
#  '\n배열',
#  ' 해싱',
#  ' map',
#  ' 정렬',
#  ' 조합',
#  ' DFS',
#  ' 정렬',
#  ' 시뮬레이션',
#  ' 트리 순회',
#  ' 구현',
#  '\nBFS',
#  ' 세그먼트 트리',
#  ' 완전탐색',
#  ' 자료구조',
#  ' 다익스트라 ',
#  '\n구현',
#  ' 정렬',
#  '문자열',
#  '트라이',
#  '\nBitwise',
#  ' 문자열',
#  ' 구현',
#  ' 정렬',
#  ' 시뮬레이션',
#  ' 스케쥴링',
#  '\n구현',
#  ' 문자열',
#  ' 시뮬레이션',
#  ' 덱',
#  '\n구현',
#  ' BFS',
#  ' DFS',
#  ' DP',
#  '\n모노톤 스택',
#  ' 그래프',
#  '\n플러드 필',
#  '\n구현',
#  ' 시뮬레이션',
#  '\nTrie',
# ...
